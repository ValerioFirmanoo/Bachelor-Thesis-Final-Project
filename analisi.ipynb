# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import os
import os.path
import scipy 
import networkx as nx
#from math import pow
import math
import cmath
from numpy.polynomial.polynomial import polyfit

#Carica librerie python e libreria funzioni.py

# %run function.py

# %% [markdown]
#  # C'È LA REPLICA 509 NEI DATI DI MIA CHE NON È PALESEMENTE UN P1LONGORI3 QUINDI LA TOLGO DAL DATASET, PER QUESTO HO 3 REPLICHE DEL P1LONGORI INVECE CHE 4 COME APPAIONO NEL DATASET

# %%
p1longori3_index_sbagliato
# Out:
# array([20160229, 20160308, 20160323, 20160509])

# %%
#P1longori plot di tutte le repliche
fig=plt.figure(num=None, figsize=(10, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )

ax.set_xlabel("Tempo", fontsize=15)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

for i in p1longori3_index_sbagliato:
    df_p1longori=read_replica_tot('P1longori3',i)
    t_bin_mean=bin_mean(df_p1longori.tTrans,(df_p1longori.Itot/df_p1longori.V),10,20,-300,400,interval='custom')
    ax.set_xlim(-300,400)
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-',markersize=4, linewidth=2, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#P1longori plot di tutte le repliche
fig=plt.figure(num=None, figsize=(10, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )

ax.set_xlabel("Tempo", fontsize=15)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

for i in p1longori3_index:
    df_p1longori=read_replica_tot('P1longori3',i)
    t_bin_mean=bin_mean(df_p1longori.tTrans,(df_p1longori.Itot/df_p1longori.V),10,20,-300,400,interval='custom')
    ax.set_xlim(-300,400)
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-',markersize=4, linewidth=2, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

plt.savefig('/home/valerio/tesi/images/P1longori_replicas.pdf')

# %%
#plot correto P1longori repliche unificate

fig=plt.figure(num=None, figsize=(10, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("Tempo", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p1longori=unify_replicas_tot('P1longori3', p1longori3_index)

t_bin_mean=bin_mean(unified_p1longori.tTrans,(unified_p1longori.Itot/unified_p1longori.V),10,20,-300,400,interval='custom')
ax.set_xlim(-300,400)
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-',markersize=4, linewidth=2, label= 'repliche unificate')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
#VARIANTE INGLESE
fig=plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )

ax.set_xlabel("Time", fontsize=35)
ax.set_ylabel('Fluorescence/Volume', fontsize=40)
ax.tick_params(which='major', length=10, labelsize=25)
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))

for i in p1ori3_index:
    df_p1longori=read_replica_tot('P1ori3',i)
    t_bin_mean=bin_mean(df_p1longori.tTrans,(df_p1longori.Itot/df_p1longori.V),10,20,-300,400,interval='custom')
    ax.set_xlim(-300,400)
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-',markersize=4, linewidth=4, label= str(i))
    ax.legend(fontsize=25, title='Replicas',title_fontsize=30)

plt.savefig('/home/valerio/tesi/images/P1ori_replicas_eng.pdf')

# %%
#plot correto P1longter repliche

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("Tempo", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)


for i in p1longter3_index:
    df_p1longter=read_replica_tot('P1longter3',i)
    t_bin_mean=bin_mean(df_p1longter.tTrans,(df_p1longter.Itot/df_p1longter.V),10,20,-300,400,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-' ,markersize=4,linewidth=2, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#plot correto P1longter repliche unificate

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("Tempo", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p1longter=unify_replicas_tot('P1longter3', p1longter3_index)

t_bin_mean=bin_mean(unified_p1longter.tTrans,(unified_p1longter.Itot/unified_p1longter.V),10,20,-300,400,interval='custom')
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-',markersize=4, linewidth=2, label= 'unified replicas')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # P1ter mi sembra strano...

# %%
#plot correto P1ter repliche

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)
#ax.set_xlim(-100,200)

for i in p1ter3_index:
    df_p1ter=read_replica_tot('P1ter3',i)
    t_bin_mean=bin_mean(df_p1ter.tTrans,(df_p1ter.Itot/df_p1ter.V),4,20,-300,400,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-' ,markersize=4,linewidth=0.7, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#plot correto P5ori repliche

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)


for i in p5ori3_index:
    df_p5ori=read_replica_tot('P5ori3',i)
    t_bin_mean=bin_mean(df_p5ori.tTrans,(df_p5ori.Itot/df_p5ori.V),10,20,-300,400,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-' ,markersize=4,linewidth=0.7, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#plot correto P5ter repliche inglese

fig=plt.figure(num=None, figsize=(12, 8), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("Time", fontsize=35)
ax.set_ylabel('Fluorescence/Volume', fontsize=40)
ax.tick_params(which='major', length=10, labelsize=25)
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))


for i in p5ter3_index:
    df_p5ori=read_replica_tot('P5ter3',i)
    t_bin_mean=bin_mean(df_p5ori.tTrans,(df_p5ori.Itot/df_p5ori.V),10,20,-300,400,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-' ,markersize=4,linewidth=4, label= str(i))
    ax.legend(fontsize=25, title='Replicas',title_fontsize=15)

plt.savefig('/home/valerio/tesi/images/P5ter_replicas_eng.pdf')

# %%
#plot correto p5ter repliche unificate

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("Tempo", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p5ter=unify_replicas_tot('P5ter3', p5ter3_index)

t_bin_mean=bin_mean(unified_p5ter.tTrans,(unified_p5ter.Itot/unified_p5ter.V),10,20,-300,400,interval='custom')
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, '-',markersize=4, linewidth=2, label= 'repliche unificate')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # in questa sezione faccio i plot delle fluorescenze, e facendo i fit della relazione ϕR+ϕP=1 trovo le costanti che legano fluorescenza su volume e settore

# %% [markdown]
# in particolare ϕR+ϕP=1 tramite calcoli diventa A1*(Ip1/Vp1)+A2*(Ip5/Vp5)=1, quindi fittando questa relazione con i dati che ho trovo le du costanti A1 e A2 che legano la fluorescenza ai settori

# %%
#p1ori p5ter e somma

fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax1 = fig.add_subplot(3,1,1)
ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Fluorescenza/Volume', fontsize=15)

ax1.set_xlim(-100,400)



ax2 = fig.add_subplot(3,1,2)
ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('Fluorescenza/Volume', fontsize=15)

ax2.set_xlim(-100,400)

#ax3 = fig.add_subplot(3,1,3)
#ax3.set_xlabel("time", fontsize=15)
#ax3.set_ylabel('somma', fontsize=15)

#ax3.set_xlim(-100,200)
#ax3.set_ylim(0.5e06,1.5e06)


unified_p5ter=unify_replicas_tot('P5ter3', p5ter3_index)
unified_p1ori=unify_replicas_tot('P1ori3', p1ori3_index)

p5ter_fluo_mean=bin_mean(unified_p5ter.tTrans,(unified_p5ter.Itot/unified_p5ter.V),4,20,-300,400,interval='custom')
p1ori_fluo_mean=bin_mean(unified_p1ori.tTrans,(unified_p1ori.Itot/unified_p1ori.V),4,20,-300,400,interval='custom')


ax2.plot(np.linspace(-300,400,len(p5ter_fluo_mean)),p5ter_fluo_mean, 'ro-',markersize=4, linewidth=0.7, label= 'unified replicas p5ter')
ax1.plot(np.linspace(-300,400,len(p1ori_fluo_mean)),p1ori_fluo_mean, 'o-',markersize=4, linewidth=0.7, label= 'unified replicas P1ori')
#ax3.plot(np.linspace(-300,400,len(t_bin_mean2)),np.array(t_bin_mean2)+np.array(t_bin_mean1), 'go-',markersize=4, linewidth=0.7, label= 'sum')


ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
fluo_params2,pcov2=scipy.optimize.curve_fit(fit_func_fluo, p5ter_fluo_mean, p1ori_fluo_mean)

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax3 = fig.add_subplot(3,1,3)
ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('somma', fontsize=15)

ax3.set_xlim(-100,400)
ax3.set_ylim(0.35,0.75)


ax3.plot(np.linspace(-300,400,len(p1ori_fluo_mean)),(fluo_params2[0]*np.array(p1ori_fluo_mean))+(fluo_params2[1]*np.array(p5ter_fluo_mean)), 'go-',markersize=4, linewidth=0.7, label= 'sum')
ax3.axhline(0.55, linestyle='--', color='grey')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax1 = fig.add_subplot(3,1,1)
ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Fluorescenza/Volume', fontsize=15)

ax1.set_xlim(-100,400)

ax2 = fig.add_subplot(3,1,2)
ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('Fluorescenza/Volume', fontsize=15)

ax2.set_xlim(-100,400)


unified_p5ter=unify_replicas_tot('P5ter3', p5ter3_index)
unified_p1longori=unify_replicas_tot('P1longori3', p1longori3_index)

p5ter_fluo_mean=bin_mean(unified_p5ter.tTrans,(unified_p5ter.Itot/unified_p5ter.V),4,20,-300,400,interval='custom')
p1longori_fluo_mean=bin_mean(unified_p1longori.tTrans,(unified_p1longori.Itot/unified_p1longori.V),4,20,-300,400,interval='custom')


ax2.plot(np.linspace(-300,400,len(p5ter_fluo_mean)),p5ter_fluo_mean, 'ro-',markersize=4, linewidth=0.7, label= 'unified replicas P5ter')
ax1.plot(np.linspace(-300,400,len(p1longori_fluo_mean)),p1longori_fluo_mean, 'o-',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
fluo_params,pcov=scipy.optimize.curve_fit(fit_func_fluo, p5ter_fluo_mean, p1longori_fluo_mean )

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax3 = fig.add_subplot(3,1,3)
ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('somma', fontsize=15)

ax3.set_xlim(-100,400)
ax3.set_ylim(0.35,0.75)

ax3.plot(np.linspace(-300,400,len(p1ori_fluo_mean)),(fluo_params[0]*np.array(p1longori_fluo_mean))+(fluo_params[1]*np.array(p5ter_fluo_mean)), 'go-',markersize=4, linewidth=0.7, label= 'sum')
ax3.axhline(0.55, linestyle='--', color='grey')

# %% [markdown]
# # P1LONGORI E P5TER SONO QUELLI CHE SEMBRANO FUNZIONARE MEGLIO

# %%
# a questo punto, conosco le costanti, posso ricavare i settori
p1longori_phi_r=fluo_params[0]*np.array(p1longori_fluo_mean)
p5ter_phi_p=fluo_params[1]*np.array(p5ter_fluo_mean)

# %% [markdown]
# # faccio anche il clacolo dei settori con p1ori e p5ter che mi servirà in seguito

# %%
fluo_params3,pcov3=scipy.optimize.curve_fit(fit_func_fluo, p5ter_fluo_mean, p1ori_fluo_mean )

# %%
# a questo punto, conosco le costanti, posso ricavare i settori
p1ori_phi_r=fluo_params3[0]*np.array(p1ori_fluo_mean)
p5ter_phi_p=fluo_params3[1]*np.array(p5ter_fluo_mean)

# %%
fig=plt.figure(num=None, figsize=(15, 10), dpi=80, facecolor='w', edgecolor='k')
ax1 = fig.add_subplot(3,1,1)
#ax1.set_xlabel("Tempo", fontsize=15)
ax1.set_ylabel('$\phi_R$', fontsize=22)

ax1.set_xlim(-100,300)
ax1.set_title('Concentrazioni dei settori con i proxies P1ori e P5ter', fontsize=20)

ax2 = fig.add_subplot(3,1,2)
#ax2.set_xlabel("Tempo", fontsize=15)
ax2.set_ylabel('$\phi_P$', fontsize=22)

ax2.set_xlim(-100,300)

ax3 = fig.add_subplot(3,1,3)
ax3.set_xlabel("Tempo", fontsize=20)
ax3.set_ylabel('$\phi_R$+$\phi_P$', fontsize=22)

ax3.set_xlim(-100,300)
ax3.set_ylim(0.35,0.75)

ax3.plot(np.linspace(-300,400,len(p1ori_phi_r)),np.array(p5ter_phi_p)+np.array(p1ori_phi_r), 'g-',markersize=4, linewidth=2, label= 'P1ori+P5ter')
ax3.axhline(0.55, linestyle='--', color='grey', label='$\phi_{Rmax}$')
ax2.plot(np.linspace(-300,400,len(p5ter_phi_p)),p5ter_phi_p, 'r-',markersize=4, linewidth=2, label= 'P5ter')
ax1.plot(np.linspace(-300,400,len(p1ori_phi_r)),p1ori_phi_r, '-',markersize=4, linewidth=2, label= 'P1ori')
ax1.axvline(x=0, linestyle='--', color='grey')
ax2.axvline(x=0, linestyle='--', color='grey')
ax3.axvline(x=0, linestyle='--', color='grey')


#ax1.tick_params(which='major', width=1.0, labelsize=15)
ax1.tick_params(which='major', length=10, labelsize=15)
ax2.tick_params(which='major', length=10, labelsize=15)
ax3.tick_params(which='major', length=10, labelsize=15)


ax1.legend(fontsize=15)
ax2.legend(fontsize=15)
ax3.legend(fontsize=14)
plt.savefig('/home/valerio/tesi/images/P1ori_settori.pdf')

# %%
#VARIANTE INGLESE
fig=plt.figure(num=None, figsize=(13, 11), dpi=80, facecolor='w', edgecolor='k')
ax1 = fig.add_subplot(3,1,1)

#ax1.set_xlabel("Tempo", fontsize=15)
ax1.set_ylabel('$\phi_R$', fontsize=35)

ax1.set_xlim(-100,300)
ax1.set_title('Sector concentration using P1ori and P5ter as proxies', fontsize=30)

ax2 = fig.add_subplot(3,1,2)
#ax2.set_xlabel("Tempo", fontsize=15)
ax2.set_ylabel('$\phi_P$', fontsize=35)

ax2.set_xlim(-100,300)

ax3 = fig.add_subplot(3,1,3)
ax3.set_xlabel("Time", fontsize=35)
ax3.set_ylabel('$\phi_R$+$\phi_P$', fontsize=35)

ax3.set_xlim(-100,300)
ax3.set_ylim(0.35,0.75)

ax3.plot(np.linspace(-300,400,len(p1ori_phi_r)),np.array(p5ter_phi_p)+np.array(p1ori_phi_r), 'g-',markersize=4, linewidth=4, label= 'P1ori+P5ter')
ax3.axhline(0.55, linestyle='--', color='grey', label='$\phi_{Rmax}$')
ax2.plot(np.linspace(-300,400,len(p5ter_phi_p)),p5ter_phi_p, 'r-',markersize=4, linewidth=4, label= 'P5ter')
ax1.plot(np.linspace(-300,400,len(p1ori_phi_r)),p1ori_phi_r, '-',markersize=4, linewidth=4, label= 'P1ori')
ax1.axvline(x=0, linestyle='--', color='black')
ax2.axvline(x=0, linestyle='--', color='black')
ax3.axvline(x=0, linestyle='--', color='black')


#ax1.tick_params(which='major', width=1.0, labelsize=15)
ax1.tick_params(which='major', length=10, labelsize=25)
ax2.tick_params(which='major', length=10, labelsize=25)
ax3.tick_params(which='major', length=10, labelsize=25)

ax1.text(3,0.30,'Nurient shift', fontsize=25)


ax1.legend(fontsize=25)
ax2.legend(fontsize=25)
ax3.legend(fontsize=20)
plt.savefig('/home/valerio/tesi/images/P1ori_sectors.pdf')

# %%
#plot aggiuntivo per far vedere che con le costanti trovate funziona abbastanza bene il fatto che 1-phi_R=phi_P

fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax3 = fig.add_subplot(3,1,3)
ax3.set_xlabel("Tempo", fontsize=15)
ax3.set_ylabel('$\phi_R$+$\phi_P$', fontsize=15)

ax3.set_xlim(-100,200)
ax3.set_ylim(0.35,0.75)

ax3.plot(np.linspace(-300,400,len(p1ori_phi_r)),np.array(p5ter_phi_p)+np.array(p1ori_phi_r), 'g-',markersize=4, linewidth=2, label= 'P1ori+P5ter')
ax3.axhline(0.55, linestyle='--', color='grey', label='$\phi_{Rmax}$')

# %% [markdown]
# # sezione dedicata a derivate e calcolo di growth rate P1ori

# %%
#aggiungo al dataframe una colonna di zeri che è il growth rate, lascio le repliche separate per facilità nel calcolo del growth rate

p1ori_r1=read_replica_tot('P1ori3',p1ori3_index[0])
p1ori_r2=read_replica_tot('P1ori3',p1ori3_index[1])


p1ori_r1=p1ori_r1.drop(['w','L','growthRateL2_0','area','growthRatearea2_0','growthRateV2_0','SA','growthRateSA2_0','beta2SA_V_2_0','xCM','yCM','orientation'],axis='columns')
p1ori_r2=p1ori_r2.drop(['w','L','growthRateL2_0','area','growthRatearea2_0','growthRateV2_0','SA','growthRateSA2_0','beta2SA_V_2_0','xCM','yCM','orientation'],axis='columns')

# %run function.py

gg1=p1ori_r1.groupby(['fov','line','cellID'])
gg2=p1ori_r2.groupby(['fov','line','cellID'])

# %%
#creo array ausiliari che servono solo come appoggio nel calcolo

array_appoggio_p1ori_1=np.empty(0)
array_appoggio_p1ori_2=np.empty(0)

# %%
#calcolo della derivata temporale iterando su tutte le cellule,identificate da (fov,line,cellID)
for name, group in gg1:
    df_p1ori_1=gg1.get_group(name).reset_index()
    array_appoggio_p1ori_1=np.append(array_appoggio_p1ori_1 , derivata_sg(np.array(df_p1ori_1['tTrans']),np.array(df_p1ori_1['V'])))
    #print(name)
for name, group in gg2:    
    df_p1ori_2=gg2.get_group(name).reset_index()
    array_appoggio_p1ori_2=np.append(array_appoggio_p1ori_2 , derivata_sg(np.array(df_p1ori_2['tTrans']),np.array(df_p1ori_2['V'])))

# %%
#aggiungo la colonna delle derivate al dataframe
p1ori_r1=p1ori_r1.join(pd.Series(array_appoggio_p1ori_1,name='der'))
p1ori_r2=p1ori_r2.join(pd.Series(array_appoggio_p1ori_2,name='der'))

# %% [markdown]
# # plot P1ori replica 1 serie temporale growth rate

# %%
std_p1ori_1=(p1ori_r1['der']/p1ori_r1['V']).std()
mean_p1ori_1=(p1ori_r1['der']/p1ori_r1['V']).mean()

p1ori_r1=p1ori_r1[((p1ori_r1['der']/p1ori_r1['V'])< mean_p1ori_1 + 3*std_p1ori_1) & ((p1ori_r1['der']/p1ori_r1['V'])> mean_p1ori_1 - 3*std_p1ori_1)]
growth_mean_p1ori_1=bin_mean(p1ori_r1.tTrans,(p1ori_r1.der/p1ori_r1.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_mean_p1ori_1=bin_mean(p1ori_r1.tTrans,(p1ori_r1.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)


ax2.plot(np.linspace(-300,400,len(growth_mean_p1ori_1)),growth_mean_p1ori_1, 'bo-',markersize=4, linewidth=0.7, label= 'replica 0222')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_mean_p1ori_1)),volume_mean_p1ori_1, 'bo-',markersize=4, linewidth=0.7, label= 'replica 0222')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # plot P1ori replica 2 serie temporale growth rate

# %%
std_p1ori_2=(p1ori_r2['der']/p1ori_r2['V']).std()
mean_p1ori_2=(p1ori_r2['der']/p1ori_r2['V']).mean()

p1ori_r2=p1ori_r2[((p1ori_r2['der']/p1ori_r2['V'])< mean_p1ori_2 + 3*std_p1ori_2) & ((p1ori_r2['der']/p1ori_r2['V'])> mean_p1ori_2 - 3*std_p1ori_2)]
growth_mean_p1ori_2=bin_mean(p1ori_r2.tTrans,(p1ori_r2.der/p1ori_r2.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_mean_p1ori_2=bin_mean(p1ori_r2.tTrans,(p1ori_r2.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)


ax2.plot(np.linspace(-300,400,len(growth_mean_p1ori_2)),growth_mean_p1ori_2, 'go-',markersize=4, linewidth=0.7, label= 'replica 0320')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_mean_p1ori_2)),volume_mean_p1ori_2, 'go-',markersize=4, linewidth=0.7, label= 'replica 0320')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # plot P1ori repliche unite serie temporale growth rate

# %%
unified_p1ori_new=pd.concat([p1ori_r1,p1ori_r2], ignore_index=True)

# %%
std_p1ori_u=(unified_p1ori_new['der']/unified_p1ori_new['V']).std()
mean_p1ori_u=(unified_p1ori_new['der']/unified_p1ori_new['V']).mean()

unified_p1ori_new=unified_p1ori_new[((unified_p1ori_new['der']/unified_p1ori_new['V'])< mean_p1ori_u + 3*std_p1ori_u) & ((unified_p1ori_new['der']/unified_p1ori_new['V'])> mean_p1ori_u - 3*std_p1ori_u)]
growth_mean_p1ori_u=bin_mean(unified_p1ori_new.tTrans,(unified_p1ori_new.der/unified_p1ori_new.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_mean_p1ori_u=bin_mean(unified_p1ori_new.tTrans,(unified_p1ori_new.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 10), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)

ax2.set_ylim(0.015,0.0275)

ax2.plot(np.linspace(-300,400,len(growth_mean_p1ori_u)),growth_mean_p1ori_u, 'ro-',markersize=4, linewidth=0.7, label= 'repliche unite')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_mean_p1ori_u)),volume_mean_p1ori_u, 'ro-',markersize=4, linewidth=0.7, label= 'repliche unite')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # sezione dedicata a derivate e calcolo di growth rate P1longori

# %%
#aggiungo al dataframe una colonna di zeri che è il growth rate, lascio le repliche separate per facilità nel calcolo del growth rate

p1longori_r1=read_replica_tot('P1longori3',p1longori3_index[0])
p1longori_r2=read_replica_tot('P1longori3',p1longori3_index[1])
p1longori_r3=read_replica_tot('P1longori3',p1longori3_index[2])


p1longori_r1=p1longori_r1.drop(['w','L','growthRateL2_0','area','growthRatearea2_0','growthRateV2_0','SA','growthRateSA2_0','beta2SA_V_2_0','xCM','yCM','orientation'],axis='columns')
p1longori_r2=p1longori_r2.drop(['w','L','growthRateL2_0','area','growthRatearea2_0','growthRateV2_0','SA','growthRateSA2_0','beta2SA_V_2_0','xCM','yCM','orientation'],axis='columns')
p1longori_r3=p1longori_r3.drop(['w','L','growthRateL2_0','area','growthRatearea2_0','growthRateV2_0','SA','growthRateSA2_0','beta2SA_V_2_0','xCM','yCM','orientation'],axis='columns')

# %run function.py

g1=p1longori_r1.groupby(['fov','line','cellID'])
g2=p1longori_r2.groupby(['fov','line','cellID'])
g3=p1longori_r3.groupby(['fov','line','cellID'])

# %%
#creo array ausiliari che servono solo come appoggio nel calcolo

array_appoggio1=np.empty(0)
array_appoggio2=np.empty(0)
array_appoggio3=np.empty(0)

# %%
#calcolo della derivata temporale iterando su tutte le cellule,identificate da (fov,line,cellID)
for name, group in g1:
    df1=g1.get_group(name).reset_index()
    array_appoggio1=np.append(array_appoggio1 , derivata_sg(np.array(df1['tTrans']),np.array(df1['V'])))

for name, group in g2:    
    df2=g2.get_group(name).reset_index()
    array_appoggio2=np.append(array_appoggio2 , derivata_sg(np.array(df2['tTrans']),np.array(df2['V'])))

for name, group in g3:
    df3=g3.get_group(name).reset_index()
    array_appoggio3=np.append(array_appoggio3 , derivata_sg(np.array(df3['tTrans']),np.array(df3['V'])))

# %%
#aggiungo la colonna delle derivate al dataframe
p1longori_r1=p1longori_r1.join(pd.Series(array_appoggio1,name='der'))
p1longori_r2=p1longori_r2.join(pd.Series(array_appoggio2,name='der'))
p1longori_r3=p1longori_r3.join(pd.Series(array_appoggio3,name='der'))

# %% [markdown]
# # plot P1longori replica 1 serie temporale growth rate

# %%
std1=(p1longori_r1['der']/p1longori_r1['V']).std()
mean1=(p1longori_r1['der']/p1longori_r1['V']).mean()

p1longori_r1=p1longori_r1[((p1longori_r1['der']/p1longori_r1['V'])< mean1 + 3*std1) & ((p1longori_r1['der']/p1longori_r1['V'])> mean1 - 3*std1)]
growth_mean1=bin_mean(p1longori_r1.tTrans,(p1longori_r1.der/p1longori_r1.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_mean1=bin_mean(p1longori_r1.tTrans,(p1longori_r1.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)


ax2.plot(np.linspace(-300,400,len(growth_mean1)),growth_mean1, 'bo-',markersize=4, linewidth=0.7, label= 'replica 0229')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_mean1)),volume_mean1, 'bo-',markersize=4, linewidth=0.7, label= 'replica 0229')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # plot P1longori replica 2 serie temporale growth rate

# %%
std2=(p1longori_r2['der']/p1longori_r2['V']).std()
mean2=(p1longori_r2['der']/p1longori_r2['V']).mean()

p1longori_r2=p1longori_r2[((p1longori_r2['der']/p1longori_r2['V'])< mean2 + 3*std2) & ((p1longori_r2['der']/p1longori_r2['V'])> mean2 - 3*std2)]
growth_mean2=bin_mean(p1longori_r2.tTrans,(p1longori_r2.der/p1longori_r2.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_mean2=bin_mean(p1longori_r2.tTrans,(p1longori_r2.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)


ax2.plot(np.linspace(-300,400,len(growth_mean2)),growth_mean2, 'go-',markersize=4, linewidth=0.7, label= 'replica 0308')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_mean2)),volume_mean2, 'go-',markersize=4, linewidth=0.7, label= 'replica 0308')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # plot P1longori replica 3 serie temporale growth rate

# %%
std3=(p1longori_r3['der']/p1longori_r3['V']).std()
mean3=(p1longori_r3['der']/p1longori_r3['V']).mean()

p1longori_r3=p1longori_r3[((p1longori_r3['der']/p1longori_r3['V'])< mean3 + 3*std3) & ((p1longori_r3['der']/p1longori_r3['V'])> mean3 - 3*std3)]
growth_mean3=bin_mean(p1longori_r3.tTrans,(p1longori_r3.der/p1longori_r3.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_mean3=bin_mean(p1longori_r3.tTrans,(p1longori_r3.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)


ax2.plot(np.linspace(-300,400,len(growth_mean3)),growth_mean3, 'ro-',markersize=4, linewidth=0.7, label= 'replica 0323')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_mean3)),volume_mean3, 'ro-',markersize=4, linewidth=0.7, label= 'replica 0323')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # plot P1longori repliche unite serie temporale growth rate

# %%
unified_new=pd.concat([p1longori_r1,p1longori_r2,p1longori_r3], ignore_index=True)

# %%
stdu=(unified_new['der']/unified_new['V']).std()
meanu=(unified_new['der']/unified_new['V']).mean()

unified_new=unified_new[((unified_new['der']/unified_new['V'])< meanu + 3*stdu) & ((unified_new['der']/unified_new['V'])> meanu - 3*stdu)]
growth_meanu=bin_mean(unified_new.tTrans,(unified_new.der/unified_new.V),4,20,-300,400,interval='custom')
#unified_mod[unified_mod['tTrans']>100]
volume_meanu=bin_mean(unified_new.tTrans,(unified_new.V),4,20,-300,400,interval='custom')

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')
ax2 = fig.add_subplot(2,1,2)
ax1= fig.add_subplot(2,1,1)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('growth_rate', fontsize=15)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('Volume', fontsize=15)

ax2.set_xlim(-100,200)
ax1.set_xlim(-100,200)


ax2.plot(np.linspace(-300,400,len(growth_meanu)),growth_meanu, 'ro-',markersize=4, linewidth=0.7, label= 'repliche unite')
#ax3.plot(p1longori_r3['tTrans'],p1longori_r3['der']/p1longori_r3['V'], 'go',markersize=4, linewidth=0.7, label= 'unified replicas P1longori')
ax1.plot(np.linspace(-300,400,len(volume_meanu)),volume_meanu, 'ro-',markersize=4, linewidth=0.7, label= 'repliche unite')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # CALCOLO E PLOT DI $\sigma$, tramite equazione $\sigma$=$\lambda_bs /\phi_R$. CON P1ORI

# %%
#aggiungo una colonna al dataset col growth_rate_bs
unified_p1ori_new=unified_p1ori_new.join(pd.Series(unified_p1ori_new.der/unified_p1ori_new.V, name='growth_rate'))

# %%
#calcolo sigma
sigma_p1ori=(growth_mean_p1ori_u/p1ori_phi_r)

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3= fig.add_subplot(3,1,3)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('growth_rate', fontsize=15)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=15)

ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax1.set_xlim(-100,300)
ax2.set_xlim(-100,300)
ax3.set_xlim(-100,300)

ax1.set_ylim(0.017,0.0245)

ax1.plot(np.linspace(-300,400,len(growth_mean_p1ori_u)),growth_mean_p1ori_u, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1ori')
ax2.plot(np.linspace(-300,400,len(p1ori_phi_r)),p1ori_phi_r, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1ori')
ax3.plot(np.linspace(-300,400,len(sigma_p1ori)),sigma_p1ori, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1ori')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)
ax3.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # CALCOLO E PLOT DI $\sigma$, tramite equazione $\sigma$=$\lambda_bs /\phi_R$. CON P1LONGORI

# %%
#aggiungo una colonna al dataset col growth_rate_bs (non serve a niente in realtà)
#unified_p1ori_new=unified_p1ori_new.join(pd.Series(unified_p1ori_new.der/unified_p1ori_new.V, name='growth_rate'))

# %%
#calcolo sigma
sigma_p1longori=(growth_meanu/p1longori_phi_r)

# %%
fig=plt.figure(num=None, figsize=(12, 13), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(3,1,1)
ax2 = fig.add_subplot(3,1,2)
ax3= fig.add_subplot(3,1,3)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('growth_rate', fontsize=15)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=15)

ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax1.set_xlim(-100,300)
ax2.set_xlim(-100,300)
ax3.set_xlim(-100,300)

ax1.set_ylim(0.017,0.023)

ax1.plot(np.linspace(-300,400,len(growth_meanu)),growth_meanu, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1longori')
ax2.plot(np.linspace(-300,400,len(p1longori_phi_r)),p1longori_phi_r, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1longori')
ax3.plot(np.linspace(-300,400,len(sigma_p1longori)),sigma_p1longori, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1longori')

ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)
ax3.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
#creo 2 dataset che contengano i dati bin-mediati per organizzare meglio i plot
p1longori_mean_df=pd.DataFrame({'time':np.linspace(-300,400,len(growth_meanu)), 'growth_rate': growth_meanu,'phi_r': p1longori_phi_r, 'sigma': sigma_p1longori})
p1ori_mean_df=pd.DataFrame({'time':np.linspace(-300,400,len(growth_meanu)),'growth_rate': growth_mean_p1ori_u,'phi_r': p1ori_phi_r, 'sigma': sigma_p1ori})

# %% [markdown]
# # CALCOLO E PLOT DI $\chi_R$

# %%
p1longori_d_phi_r=derivata(np.linspace(-300,400,len(growth_meanu)),p1longori_mean_df.phi_r)

p1longori_mean_df=p1longori_mean_df.join(pd.Series(p1longori_d_phi_r, name= 'd_phi_r'))

p1longori_chi_r=((1/(p1longori_mean_df.sigma*p1longori_mean_df.phi_r))*p1longori_mean_df.d_phi_r)+p1longori_mean_df.phi_r

p1longori_mean_df=p1longori_mean_df.join(pd.Series(p1longori_chi_r, name= 'chi_r'))

# %%
p1ori_d_phi_r=derivata(np.linspace(-300,400,len(growth_meanu)),p1ori_mean_df.phi_r)

p1ori_mean_df=p1ori_mean_df.join(pd.Series(p1ori_d_phi_r, name= 'd_phi_r'))

p1ori_chi_r=((1/(p1ori_mean_df.sigma*p1ori_mean_df.phi_r))*p1ori_mean_df.d_phi_r)+p1ori_mean_df.phi_r

p1ori_mean_df=p1ori_mean_df.join(pd.Series(p1ori_chi_r, name= 'chi_r'))

# %%
fig=plt.figure(num=None, figsize=(12, 15), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3= fig.add_subplot(4,1,3)
ax4= fig.add_subplot(4,1,4)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('growth_rate', fontsize=15)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=15)

ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax4.set_xlabel("time", fontsize=15)
ax4.set_ylabel('$\chi_R$', fontsize=15)

ax1.set_xlim(-100,300)
ax2.set_xlim(-100,300)
ax3.set_xlim(-100,300)
ax4.set_xlim(-100,300)


ax1.set_ylim(0.017,0.023)

ax1.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.growth_rate, 'ro-',markersize=4, linewidth=0.7, label= 'unified P1longori')
ax2.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.phi_r, 'bo-',markersize=4, linewidth=0.7, label= 'unified P1longori')
ax3.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.sigma, 'go-',markersize=4, linewidth=0.7, label= 'unified P1longori')
ax4.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.chi_r, 'o-',color='orange',markersize=4, linewidth=0.7, label= 'unified P1longori')


ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)
ax3.legend(fontsize=15, title='legend',title_fontsize=15)
ax4.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
fig=plt.figure(num=None, figsize=(12, 15), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3= fig.add_subplot(4,1,3)
ax4= fig.add_subplot(4,1,4)

ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('growth_rate', fontsize=15)

ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=15)

ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax4.set_xlabel("time", fontsize=15)
ax4.set_ylabel('$\chi_R$', fontsize=15)

ax1.set_xlim(-100,300)
ax2.set_xlim(-100,300)
ax3.set_xlim(-100,300)
ax4.set_xlim(-100,300)

ax1.set_ylim(0.017,0.0245)

ax1.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.growth_rate, 'ro-',markersize=4, linewidth=0.7, label= 'unified p1ori')
ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.phi_r, 'bo-',markersize=4, linewidth=0.7, label= 'unified p1ori')
ax3.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'go-',markersize=4, linewidth=0.7, label= 'unified p1ori')
ax4.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, 'o-',color='orange',markersize=4, linewidth=0.7, label= 'unified p1ori')



ax1.legend(fontsize=15, title='legend',title_fontsize=15)
ax2.legend(fontsize=15, title='legend',title_fontsize=15)
ax3.legend(fontsize=15, title='legend',title_fontsize=15)
ax4.legend(fontsize=15, title='legend',title_fontsize=15)

# %% [markdown]
# # Erikson FCR model falsification

# %% [markdown]
# faccio 2 plot uno con procy p1ori uno con proxy p1longori

# %%
#falsificazione erikson p1ori

fig1=plt.figure(num=None, figsize=(14, 4), dpi=80, facecolor='w', edgecolor='k')

gs=fig1.add_gridspec(2,2)
ax1=fig1.add_subplot(gs[:,0])
ax2=fig1.add_subplot(gs[0,1])
ax3=fig1.add_subplot(gs[1,1])

ax1.tick_params(which='major', length=10, labelsize=15)
ax2.tick_params(which='major', length=10, labelsize=12)
ax3.tick_params(which='major', length=10, labelsize=12)


ax1.set_title('Scatterplot $\chi_R$ vs $\sigma$ P1ori', fontsize=15)
ax2.set_title('Serie temporali $\chi_R$ e $\sigma$ P1ori', fontsize=15)

cm= plt.cm.get_cmap('jet')

ax3.set_xlim(-100,300)
ax2.set_xlim(-100,300)

ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax2.set_ylabel('$\chi_R$', fontsize=15)

ax1.set_xlabel('$\sigma$', fontsize=15)
ax1.set_ylabel('$\chi_R$', fontsize=15)

ax3.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'g-', linewidth=2)
ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, '-',color='orange', linewidth=2)
sc=ax1.scatter(p1ori_mean_df[p1ori_mean_df.time>-100].sigma, p1ori_mean_df[p1ori_mean_df.time>-100].chi_r,c=p1ori_mean_df[p1ori_mean_df.time>-100].time, cmap='jet',label='P1ori')
plt.colorbar(sc,ax=ax1, label='tempo dallo shift di nutrienti', ticks=np.linspace(-100,400,11))

ax3.axvline(x=0, linestyle='--', color='grey')
ax2.axvline(x=0, linestyle='--', color='grey')


plt.savefig('/home/valerio/tesi/images/P1ori_falsificazione1.pdf')

# %%
#fVARIANTE INGLESE

fig1=plt.figure(num=None, figsize=(15, 8), dpi=80, facecolor='w', edgecolor='k')

gs=fig1.add_gridspec(2,2)
ax1=fig1.add_subplot(gs[:,0])
ax2=fig1.add_subplot(gs[0,1])
ax3=fig1.add_subplot(gs[1,1])

ax2.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticks([])
ax1.tick_params(which='major', length=10, labelsize=20)
ax2.tick_params(which='major', length=10, labelsize=20)
ax3.tick_params(which='major', length=10, labelsize=20)



ax1.set_title('Scatterplot $\chi_R$ vs $\sigma$ P1ori', fontsize=25)
ax2.set_title('Temporal series $\chi_R$ and $\sigma$ P1ori', fontsize=25)

cm= plt.cm.get_cmap('jet')

ax3.set_xlim(-100,300)
ax2.set_xlim(-100,300)

ax3.set_xlabel("time", fontsize=30)
#ax3.set_ylabel('$\sigma$', fontsize=35)

#ax2.set_ylabel('$\chi_R$', fontsize=35)

ax1.set_xlabel('$\sigma$', fontsize=35)
ax1.set_ylabel('$\chi_R$', fontsize=35)

ax3.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'g-', linewidth=4)
ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, '-',color='orange', linewidth=4)
sc=ax1.scatter(p1ori_mean_df[p1ori_mean_df.time>-100].sigma, p1ori_mean_df[p1ori_mean_df.time>-100].chi_r,c=p1ori_mean_df[p1ori_mean_df.time>-100].time, cmap='jet',label='P1ori')
plt.colorbar(sc,ax=ax1, ticks=np.linspace(-100,400,11))


ax3.axvline(x=0, linestyle='--', color='grey')
ax2.axvline(x=0, linestyle='--', color='grey')

ax3.text(200,0.0850,'$\sigma$', fontsize=40)
ax2.text(200,0.25,'$\chi_R$', fontsize=40)


plt.savefig('/home/valerio/tesi/images/P1ori_falsification1.pdf')

# %%
#falsificazione erikson p1longori

fig1=plt.figure(num=None, figsize=(15, 5), dpi=80, facecolor='w', edgecolor='k')
gs=fig1.add_gridspec(2,2)
ax1=fig1.add_subplot(gs[:,0])
ax2=fig1.add_subplot(gs[0,1])
ax3=fig1.add_subplot(gs[1,1])

ax1.tick_params(which='major', length=10, labelsize=15)
ax2.tick_params(which='major', length=10, labelsize=12)
ax3.tick_params(which='major', length=10, labelsize=12)

ax1.set_title('Scatterplot $\chi_R$ vs $\sigma$ P1longori', fontsize=15)
ax2.set_title('Serie temporali $\chi_R$ e $\sigma$ P1longori', fontsize=15)

cm= plt.cm.get_cmap('jet')

ax3.set_xlim(-100,300)
ax2.set_xlim(-100,300)

ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax2.set_ylabel('$\chi_R$', fontsize=15)

ax1.set_xlabel('$\sigma$', fontsize=15)
ax1.set_ylabel('$\chi_R$', fontsize=15)

ax3.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.sigma, 'g-', linewidth=2)
ax2.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.chi_r, '-',color='orange', linewidth=2)
sc=ax1.scatter(p1longori_mean_df[p1longori_mean_df.time>-100].sigma, p1longori_mean_df[p1longori_mean_df.time>-100].chi_r,c=p1longori_mean_df[p1longori_mean_df.time>-100].time, cmap='jet')
plt.colorbar(sc,ax=ax1, ticks=np.linspace(-100,400,11))

ax3.axvline(x=0, linestyle='--', color='grey')
ax2.axvline(x=0, linestyle='--', color='grey')

plt.savefig('/home/valerio/tesi/images/P1ori_falsificazione2.pdf')

# %%
#VARIANTE INGLESE

fig1=plt.figure(num=None, figsize=(15,8), dpi=80, facecolor='w', edgecolor='k')
gs=fig1.add_gridspec(2,2)
ax1=fig1.add_subplot(gs[:,0])
ax2=fig1.add_subplot(gs[0,1])
ax3=fig1.add_subplot(gs[1,1])

ax1.tick_params(which='major', length=10, labelsize=20)
ax2.tick_params(which='major', length=10, labelsize=20)
ax3.tick_params(which='major', length=10, labelsize=20)

ax1.set_title('Scatterplot $\chi_R$ vs $\sigma$ P1longori', fontsize=25)
ax2.set_title('Temporal series $\chi_R$ and $\sigma$ P1longori', fontsize=25)

cm= plt.cm.get_cmap('jet')

ax3.set_xlim(-100,300)
ax2.set_xlim(-100,300)

ax3.set_xlabel("time", fontsize=30)
ax1.set_xlabel('$\sigma$', fontsize=35)
ax1.set_ylabel('$\chi_R$', fontsize=35)

ax3.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.sigma, 'g-', linewidth=4)
ax2.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.chi_r, '-',color='orange', linewidth=4)
sc=ax1.scatter(p1longori_mean_df[p1longori_mean_df.time>-100].sigma, p1longori_mean_df[p1longori_mean_df.time>-100].chi_r,c=p1longori_mean_df[p1longori_mean_df.time>-100].time, cmap='jet')
plt.colorbar(sc,ax=ax1, ticks=np.linspace(-100,400,11))

ax3.axvline(x=0, linestyle='--', color='grey')
ax2.axvline(x=0, linestyle='--', color='grey')

ax3.text(200,0.0950,'$\sigma$', fontsize=40)
ax2.text(200,0.22,'$\chi_R$', fontsize=40)



plt.savefig('/home/valerio/tesi/images/P1ori_falsification2.pdf')

# %% [markdown]
# # Minimal model

# %% [markdown]
# Il modello minimo prevede che $\chi$ e $\sigma$ siano messe "a mano" come funzioni a gradini. quindi per prima cosa mi occupo di trovare il valore di queste funzioni costanti

# %%
#equazioni: (non serve)
def growth_r_teorico (sigma, phi):
    return sigma*phi

#funzione per fit
def fit_phi (t, chi):
    ind=k
    y0=phifit[ind][0]
    
    def phi_r_teorico (phi, t , chi ):
        #sigma=0.0445
        dphi = np.array(sigma*phi)*(chi-phi)
        return dphi
    phi=scipy.integrate.odeint(phi_r_teorico, y0 , t , args=(chi,)).T[0]
    return phi

def phi_r_teorico (phi, t , chi ):
    #sigma=0.0445
    dphi = np.array(sigma*phi)*(chi-phi)
    return dphi

# %% [markdown]
# # divido il dataset nelle 4 fasce temporali da considerare per i fit
#
# p1ori_mean_prova=p1ori_mean_df[p1ori_mean_df.time>-100]
# tgraph=np.array(p1ori_mean_prova.time)
#
# tfit, phifit, sigmafit=([0]*4,[0]*4, [0]*4)
#
# tfit[0]=np.array(p1ori_mean_prova[p1ori_mean_prova['time'] <11 ].time)
# phifit[0]=np.array(p1ori_mean_prova[p1ori_mean_prova['time'] <16 ].phi_r)
# sigmafit[0]=0.074
#
# tfit[1]=np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=15) & (p1ori_mean_prova['time'] <=50) ].time)
# phifit[1]=np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=15) & (p1ori_mean_prova['time'] <=50) ].phi_r)
# sigmafit[1]=p1ori_mean_prova['sigma'].max()
#
# tfit[2]=np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=50) & (p1ori_mean_prova['time'] <=131) ].time)
# phifit[2]=np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=50) & (p1ori_mean_prova['time'] <=131) ].phi_r)
# sigmafit[2]=0.08
#
# tfit[3]=np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=130) ].time)
# phifit[3]=np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=130) ].phi_r)
# sigmafit[3]=0.08

# %%
# divido il dataset nelle 4 fasce temporali da considerare per i fit

p1ori_mean_prova=p1ori_mean_df[p1ori_mean_df.time>-100]
tgraph=np.array(p1ori_mean_prova.time)

tfit, phifit, sigmafit=([0]*4,[0]*4, [0]*4)

tfit[0]=np.array(p1ori_mean_prova[p1ori_mean_prova['time'] <18 ].time)
phifit[0]=np.array(p1ori_mean_prova[p1ori_mean_prova['time'] <18 ].phi_r)
sigmafit[0]=0.074

tfit[1]=np.append(tfit[0][-1],np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=15) & (p1ori_mean_prova['time'] <=46) ].time))
phifit[1]=np.append(phifit[0][-1],np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=15) & (p1ori_mean_prova['time'] <=46) ].phi_r))
sigmafit[1]=p1ori_mean_prova['sigma'].max()

tfit[2]=np.append(tfit[1][-1],np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=45) & (p1ori_mean_prova['time'] <=131) ].time))
phifit[2]=np.append(phifit[1][-1],np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=45) & (p1ori_mean_prova['time'] <=131) ].phi_r))
sigmafit[2]=0.0805

tfit[3]=np.append(tfit[2][-1],np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=130) ].time))
phifit[3]=np.append(phifit[2][-1],np.array(p1ori_mean_prova[(p1ori_mean_prova['time']>=130) ].phi_r))
sigmafit[3]=0.0805

# %%
phifit
# Out:
# [array([0.24283748, 0.24281378, 0.24270367, 0.24266252, 0.24245555,
#         0.24214498, 0.24206846, 0.242456  , 0.24228738, 0.24184833,
#         0.24215453, 0.24244454, 0.2424634 , 0.24271156, 0.24317989,
#         0.2434441 , 0.24354986, 0.24361007, 0.24395763, 0.24405348,
#         0.24419743, 0.24481283, 0.24507031, 0.24489941, 0.2451502 ,
#         0.24565865, 0.24540521, 0.24487348, 0.24439222, 0.24322392]),
#  array([0.24322392, 0.24322392, 0.24139537, 0.23988031, 0.23899276,
#         0.23896185, 0.23992762, 0.24219883, 0.24601019]),
#  array([0.24601019, 0.24601019, 0.24939739, 0.25299284, 0.2574092 ,
#         0.26187229, 0.26588387, 0.26952028, 0.27293069, 0.27651161,
#         0.28024059, 0.28374353, 0.28610002, 0.2884979 , 0.29080032,
#         0.29213757, 0.29395688, 0.29468142, 0.29568917, 0.29626189,
#         0.29698233, 0.29731543, 0.29683222]),
#  array([0.29683222, 0.29683222, 0.29616951, 0.29519679, 0.29415226,
# ...

# %%
p_fit,p_cov=([0]*4,[0]*4)

for k in range(4):
    sigma=sigmafit[k]
    p_fit[k],p_cov[k]=scipy.optimize.curve_fit( fit_phi , tfit[k] , phifit[k])

#correzione a mano del valore 4 che viene bruttino dal fit
p_fit[3]=0.30
p_fit[2]=0.312
p_fit[1]=0.23

# %%
chiteo, phiteo, sigmateo=([0]*4,[0]*4, [0]*4)

for j in range(4):
    sigma=sigmafit[k]
    phiteo[j]=scipy.integrate.odeint(phi_r_teorico, phifit[j], tfit[j] , args=(p_fit[j],)).T[0]

sigmateo[0]=np.full(len(tfit[0]), sigmafit[0])
for j in range(1,4):
    sigmateo[j]=np.append(sigmafit[j-1],np.full(len(tfit[j])-1, sigmafit[j]))

chiteo[0]=np.full(len(tfit[0]), p_fit[0]) 
for j in range(1,4):
    chiteo[j]=np.append(p_fit[j-1],np.full(len(tfit[j])-1, p_fit[j]))    
    

len(sigmateo[1])
# Out:
# 9

# %%
fig=plt.figure(num=None, figsize=(9, 11), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3= fig.add_subplot(4,1,3)
ax4= fig.add_subplot(4,1,4)

#ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('$\lambda_{bs}$', fontsize=25)

#ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=25)

#ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=25)

ax4.set_xlabel("time", fontsize=25)
ax4.set_ylabel('$\chi_R$', fontsize=25)

ax1.set_xlim(-100,300)
ax1.set_ylim(0.014,0.028)

ax2.set_xlim(-100,300)
ax3.set_xlim(-100,300)
ax4.set_xlim(-100,300)

ax1.axes.xaxis.set_ticklabels([])
ax2.axes.xaxis.set_ticklabels([])
ax3.axes.xaxis.set_ticklabels([])


ax1.tick_params(which='major', length=7, labelsize=12.5,direction='in')
ax2.tick_params(which='major', length=7, labelsize=12.5,direction='in')
ax3.tick_params(which='major', length=7, labelsize=12.5,direction='in')
ax4.tick_params(which='major', length=7, labelsize=12.5,direction='in')


ax1.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.growth_rate, '-',color='dodgerblue',markersize=4, linewidth=2, label= 'p1ori data')
ax1.plot(tfit[0],phiteo[0] * sigmafit[0], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7, label= 'minimal model')
ax1.plot(tfit[1],phiteo[1] * sigmafit[1], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7)
ax1.plot(tfit[2],phiteo[2] * sigmafit[2], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7)
ax1.plot(tfit[3],phiteo[3] * sigmafit[3], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7)

ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.phi_r, 'b-',markersize=4, linewidth=2, label= 'p1ori data')
ax2.plot(tfit[0],phiteo[0], 'ro',fillstyle='none',markersize=4, linewidth=0.7, label= 'minimal model')
ax2.plot(tfit[1],phiteo[1], 'ro',fillstyle='none',markersize=4, linewidth=0.7)
ax2.plot(tfit[2],phiteo[2], 'ro',fillstyle='none',markersize=4, linewidth=0.7)
ax2.plot(tfit[3],phiteo[3], 'ro',fillstyle='none',markersize=4, linewidth=0.7)

ax3.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'g-',markersize=4, linewidth=2, label= 'p1ori data')
ax3.plot(tfit[0],sigmateo[0], 'r-',markersize=4, linewidth=1.5, label= 'minimal model imput')
ax3.plot(tfit[1],sigmateo[1], 'r-',markersize=4, linewidth=1.5)
ax3.plot(tfit[2],sigmateo[2], 'r-',markersize=4, linewidth=1.5)
ax3.plot(tfit[3],sigmateo[3], 'r-',markersize=4, linewidth=1.5)


ax4.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, '-',color='black',markersize=4, linewidth=2, label= 'p1ori data')
ax4.plot(tfit[0],chiteo[0], 'r-',markersize=4, linewidth=1.5, label= 'minimal model imput')
ax4.plot(tfit[1],chiteo[1], 'r-',markersize=4, linewidth=1.5)
ax4.plot(tfit[2],chiteo[2], 'r-',markersize=4, linewidth=1.5)
ax4.plot(tfit[3],chiteo[3], 'r-',markersize=4, linewidth=1.5)
#ax4.plot(tgraph,chigraph, 'r-',markersize=4, linewidth=1.5)



#ax4.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, 'o-',color='orange',markersize=4, linewidth=0.7, label= 'unified p1ori')


ax1.legend(fontsize=10, title='legend',title_fontsize=10)
ax2.legend(fontsize=10, title='legend',title_fontsize=10)
ax3.legend(fontsize=10, title='legend',title_fontsize=10, loc='upper right')
ax4.legend(fontsize=10, title='legend',title_fontsize=10)

for ax in fig.axes:
    ax.axvline(x=0, linestyle='--', color='dimgrey')
    ax.axvline(x=18, linestyle='--', color='grey')
    ax.axvline(x=46, linestyle='--', color='darkgrey')
    ax.axvline(x=130, linestyle='--', color='silver')

#ax3.axvline(x=15, linestyle='-', color='red')
   # ax.axvline(x=50, linestyle='-', color='red')
    #ax.axvline(x=130, linestyle='-', color='red')

#plt.savefig('/home/valerio/tesi/images/newmodel.pdf')

# %%
fig=plt.figure(num=None, figsize=(8,5), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(2,1,1)
ax2= fig.add_subplot(2,1,2)

ax1.set_title('Grafici sperimentali di $\sigma$ e $\chi_R$', fontsize=20)


#ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('$\sigma$', fontsize=15)

ax2.set_xlabel("Tempo", fontsize=15)
ax2.set_ylabel('$\chi_R$', fontsize=20)


ax1.set_xlim(-100,300)
ax2.set_xlim(-100,300)



ax1.tick_params(which='major', length=10, labelsize=12.5)
ax2.tick_params(which='major', length=10, labelsize=12.5)




ax1.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'g-',markersize=4, linewidth=2, label= 'unified p1ori')


ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, '-',color='black',markersize=4, linewidth=2, label= 'unified p1ori')

ax1.text(-64,0.085,'Nutrient shift')


#ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, 'o-',color='orange',markersize=4, linewidth=0.7, label= 'unified p1ori')



#ax2.legend(fontsize=10, title='legend',title_fontsize=10)

for ax in fig.axes:
    ax.axvline(x=0, linestyle='--', color='dimgrey')
    ax.axvline(x=18, linestyle='--', color='grey')
    ax.axvline(x=45, linestyle='--', color='darkgrey')
    ax.axvline(x=130, linestyle='--', color='silver')
    



#ax1.axvline(x=15, linestyle='-', color='red')
   # ax.axvline(x=50, linestyle='-', color='red')
    #ax.axvline(x=130, linestyle='-', color='red')

plt.savefig('/home/valerio/tesi/images/sigmachi.pdf')

# %%
fig=plt.figure(num=None, figsize=(12,8), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(2,1,1)
ax2= fig.add_subplot(2,1,2)

ax1.set_title('P1ori experimental plot of $\sigma$ and $\chi_R$', fontsize=30)


#ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('$\sigma$', fontsize=35)

ax2.set_xlabel("Time", fontsize=30)
ax2.set_ylabel('$\chi_R$', fontsize=35)


ax1.set_xlim(-100,300)
ax2.set_xlim(-100,300)



ax1.tick_params(which='major', length=10, labelsize=25.5)
ax2.tick_params(which='major', length=10, labelsize=25.5)




ax1.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'g-',markersize=4, linewidth=4, label= 'unified p1ori')


ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, '-',color='black',markersize=4, linewidth=4, label= 'unified p1ori')




#ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, 'o-',color='orange',markersize=4, linewidth=0.7, label= 'unified p1ori')



#ax2.legend(fontsize=10, title='legend',title_fontsize=10)

for ax in fig.axes:
    ax.axvline(x=0, linestyle='--', color='dimgrey')
    ax.axvline(x=18, linestyle='--', color='grey')
    ax.axvline(x=45, linestyle='--', color='darkgrey')
    ax.axvline(x=130, linestyle='--', color='silver')
    



#ax1.axvline(x=15, linestyle='-', color='red')
   # ax.axvline(x=50, linestyle='-', color='red')
    #ax.axvline(x=130, linestyle='-', color='red')

plt.savefig('/home/valerio/tesi/images/sigmachi_inglese.pdf')

# %%
fig=plt.figure(num=None, figsize=(9, 7), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(2,1,1)
ax2= fig.add_subplot(2,1,2)

#ax1.set_xlabel("time", fontsize=15)
#ax1.set_ylabel('$\sigma$', fontsize=15)

#ax2.set_xlabel("Tempo", fontsize=20)
#ax2.set_ylabel('$\chi_R$', fontsize=20)

ax1.set_xlim(-50,200)
ax2.set_xlim(-50,200)

#ax1.set_title('Valori di')

ax1.tick_params(which='major', length=0, labelsize=12.5)
ax2.tick_params(which='major', length=0, labelsize=12.5)

ax1.set_yticklabels([])
ax1.set_xticklabels([])

ax2.set_yticklabels([])
ax2.set_xticklabels([])



#ax1.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.sigma, 'g-',markersize=4, linewidth=2, label= 'unified p1ori')
ax1.plot(tfit[0],sigmateo[0], 'r-',markersize=4, linewidth=1.5, label= 'minimal model imput')
ax1.plot(tfit[1],sigmateo[1], 'r-',markersize=4, linewidth=1.5)
ax1.plot(tfit[2],sigmateo[2], 'r-',markersize=4, linewidth=1.5)
ax1.plot(tfit[3],sigmateo[3], 'r-',markersize=4, linewidth=1.5)


#ax2.plot(np.linspace(-300,400,len(p1ori_mean_df)),p1ori_mean_df.chi_r, '-',color='black',markersize=4, linewidth=2, label= 'unified p1ori')
ax2.plot(tfit[0],chiteo[0], 'b-',markersize=4, linewidth=1.5, label= 'minimal model imput')
ax2.plot(tfit[1],chiteo[1], 'b-',markersize=4, linewidth=1.5)
ax2.plot(tfit[2],chiteo[2], 'b-',markersize=4, linewidth=1.5)
ax2.plot(tfit[3],chiteo[3], 'b-',markersize=4, linewidth=1.5)
#ax2.plot(tgraph,chigraph, 'r-',markersize=4, linewidth=1.5)

ax1.text(100, 0.085, '$\sigma_A$',horizontalalignment='center',verticalalignment='center',fontsize=30, color='red')
ax2.text(100, 0.275, '$\chi_R$',horizontalalignment='center',verticalalignment='center',fontsize=30, color='blue')



for ax in fig.axes:
    ax.axvline(x=0, linestyle='--', color='dimgrey')
    ax.axvline(x=18, linestyle='--', color='grey')
    ax.axvline(x=45, linestyle='--', color='darkgrey')
    ax.axvline(x=130, linestyle='--', color='silver')
    

ax1.axhline(y=0.074, linestyle='--', color='dimgrey', label='$\sigma^*_i$')
ax1.axhline(y=0.0805, linestyle='--', color='grey',label='$\sigma^*_{max}$')
ax1.axhline(y=0.0895 ,linestyle='--', color='darkgrey',label='$\sigma^*_f$')

ax2.axhline(y=0.300, linestyle='--', color='dimgrey')
ax2.axhline(y=0.245, linestyle='--', color='grey')
ax2.axhline(y=0.33 ,linestyle='--', color='darkgrey')


#ax1.axvline(x=15, linestyle='-', color='red')
   # ax.axvline(x=50, linestyle='-', color='red')
    #ax.axvline(x=130, linestyle='-', color='red')
plt.savefig('/home/valerio/tesi/images/scaletemporali.pdf')

# %%
tfit1, phifit, sigmafit1=([0]*4,[0]*4, [0]*4)
phifit[1]
# Out:
# 0

# %% [markdown]
# # FACCIO STESSA COSA P1LONGORI

# %%
# divido il dataset nelle 4 fasce temporali da considerare per i fit

p1longori_mean_prova=p1longori_mean_df[p1longori_mean_df.time>-100]


tfit1, phifit, sigmafit1=([0]*4,[0]*4, [0]*4)

tfit1[0]=np.array(p1longori_mean_prova[p1longori_mean_prova['time'] <18 ].time)
phifit[0]=np.array(p1longori_mean_prova[p1longori_mean_prova['time'] <18 ].phi_r)
sigmafit1[0]=0.090

tfit1[1]=np.append(tfit1[0][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=15) & (p1longori_mean_prova['time'] <=46) ].time))
phifit[1]=np.append(phifit1[0][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=15) & (p1longori_mean_prova['time'] <=46) ].phi_r))
sigmafit1[1]=p1longori_mean_prova['sigma'].max()

tfit1[2]=np.append(tfit1[1][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=45) & (p1longori_mean_prova['time'] <=131) ].time))
phifit[2]=np.append(phifit1[1][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=45) & (p1longori_mean_prova['time'] <=131) ].phi_r))
sigmafit1[2]=0.08

tfit1[3]=np.append(tfit1[2][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=130) ].time))
phifit[3]=np.append(phifit1[2][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=130) ].phi_r))
sigmafit1[3]=0.0805
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-c7e5519d092f> in <module>
#      11
#      12 tfit1[1]=np.append(tfit1[0][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=15) & (p1longori_mean_prova['time'] <=46) ].time))
# ---> 13 phifit[1]=np.append(phifit1[0][-1],np.array(p1longori_mean_prova[(p1longori_mean_prova['time']>=15) & (p1longori_mean_prova['time'] <=46) ].phi_r))
#      14 sigmafit1[1]=p1longori_mean_prova['sigma'].max()
#      15
#
# TypeError: 'int' object is not subscriptable

# %%
p_fit1,p_cov1=([0]*4,[0]*4)

for k in range(4):
    sigma=sigmafit1[k]
    p_fit1[k],p_cov1[k]=scipy.optimize.curve_fit( fit_phi , tfit1[k] , phifit1[k])

#correzione a mano del valore 4 che viene bruttino dal fit
p_fit1[3]=0.26
p_fit1[2]=0.30
p_fit1[1]=0.200
p_fit1[0]=0.200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-85cb09422c56> in <module>
#       3 for k in range(4):
#       4     sigma=sigmafit1[k]
# ----> 5     p_fit1[k],p_cov1[k]=scipy.optimize.curve_fit( fit_phi , tfit1[k] , phifit1[k])
#       6
#       7 #correzione a mano del valore 4 che viene bruttino dal fit
#
# ~/.local/lib/python3.8/site-packages/scipy/optimize/minpack.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     782         # Remove full_output from kwargs, otherwise we're passing it in twice.
#     783         return_full = kwargs.pop('full_output', False)
# --> 784         res = leastsq(func, p0, Dfun=jac, full_output=1, **kwargs)
#     785         popt, pcov, infodict, errmsg, ier = res
#     786         ysize = len(infodict['fvec'])
#
# ...

# %%
chiteo1, phiteo1, sigmateo1=([0]*4,[0]*4, [0]*4)

for j in range(4):
    sigma=sigmafit1[k]
    phiteo1[j]=scipy.integrate.odeint(phi_r_teorico, phifit[j], tfit1[j] , args=(p_fit1[j],)).T[0]

sigmateo1[0]=np.full(len(tfit1[0]), sigmafit1[0])
for j in range(1,4):
    sigmateo1[j]=np.append(sigmafit1[j-1],np.full(len(tfit1[j])-1, sigmafit1[j]))

chiteo1[0]=np.full(len(tfit1[0]), p_fit1[0]) 
for j in range(1,4):
    chiteo1[j]=np.append(p_fit1[j-1],np.full(len(tfit1[j])-1, p_fit1[j]))    
    

phiteo1[0]
# Out:
# array([0.24283748, 0.24102181, 0.23929556, 0.2376533 , 0.23609001,
#        0.23460108, 0.23318221, 0.23182942, 0.230539  , 0.22930751,
#        0.22813174, 0.22700869, 0.22593558, 0.22490979, 0.22392887,
#        0.22299051, 0.22209259, 0.22123308, 0.22041007, 0.2196218 ,
#        0.21886658, 0.21814282, 0.21744905, 0.21678384, 0.21614588,
#        0.2155339 , 0.21494672, 0.21438322, 0.21384233, 0.21332305])

# %%
fig=plt.figure(num=None, figsize=(9, 11), dpi=80, facecolor='w', edgecolor='k')

ax1= fig.add_subplot(4,1,1)
ax2 = fig.add_subplot(4,1,2)
ax3= fig.add_subplot(4,1,3)
ax4= fig.add_subplot(4,1,4)

#ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('$\lambda_{bs}$', fontsize=15)

#ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=15)

#ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=15)

ax4.set_xlabel("time", fontsize=15)
ax4.set_ylabel('$\chi_R$', fontsize=20)

ax1.set_xlim(-100,300)
ax1.set_ylim(0.014,0.028)

ax2.set_xlim(-100,300)
ax3.set_xlim(-100,300)
ax4.set_xlim(-100,300)


ax1.tick_params(which='major', length=10, labelsize=12.5)
ax2.tick_params(which='major', length=10, labelsize=12.5)
ax3.tick_params(which='major', length=10, labelsize=12.5)
ax4.tick_params(which='major', length=10, labelsize=12.5)


ax1.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.growth_rate, '-',color='orange',markersize=4, linewidth=2, label= 'unified p1longori')
ax1.plot(tfit1[0],phiteo1[0] * sigmafit1[0], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7, label= 'minimal model')
ax1.plot(tfit1[1],phiteo1[1] * sigmafit1[1], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7)
ax1.plot(tfit1[2],phiteo1[2] * sigmafit1[2], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7)
ax1.plot(tfit1[3],phiteo1[3] * sigmafit1[3], marker='o', color='red',fillstyle='none',markersize=4, linewidth=0.7)

ax2.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.phi_r, 'b-',markersize=4, linewidth=2, label= 'unified p1longori')
ax2.plot(tfit1[0],phiteo1[0], 'ro',fillstyle='none',markersize=4, linewidth=0.7, label= 'minimal model')
ax2.plot(tfit1[1],phiteo1[1], 'ro',fillstyle='none',markersize=4, linewidth=0.7)
ax2.plot(tfit1[2],phiteo1[2], 'ro',fillstyle='none',markersize=4, linewidth=0.7)
ax2.plot(tfit1[3],phiteo1[3], 'ro',fillstyle='none',markersize=4, linewidth=0.7)

ax3.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.sigma, 'g-',markersize=4, linewidth=2, label= 'unified p1longori')
ax3.plot(tfit1[0],sigmateo1[0], 'r-',markersize=4, linewidth=1.5, label= 'minimal model imput')
ax3.plot(tfit1[1],sigmateo1[1], 'r-',markersize=4, linewidth=1.5)
ax3.plot(tfit1[2],sigmateo1[2], 'r-',markersize=4, linewidth=1.5)
ax3.plot(tfit1[3],sigmateo1[3], 'r-',markersize=4, linewidth=1.5)


ax4.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.chi_r, '-',color='black',markersize=4, linewidth=2, label= 'unified p1longori')
ax4.plot(tfit1[0],chiteo1[0], 'r-',markersize=4, linewidth=1.5, label= 'minimal model imput')
ax4.plot(tfit1[1],chiteo1[1], 'r-',markersize=4, linewidth=1.5)
ax4.plot(tfit1[2],chiteo1[2], 'r-',markersize=4, linewidth=1.5)
ax4.plot(tfit1[3],chiteo1[3], 'r-',markersize=4, linewidth=1.5)
#ax4.plot(tgraph,chigraph, 'r-',markersize=4, linewidth=1.5)



#ax4.plot(np.linspace(-300,400,len(p1longori_mean_df)),p1longori_mean_df.chi_r, 'o-',color='orange',markersize=4, linewidth=0.7, label= 'unified p1longori')


ax1.legend(fontsize=10, title='legend',title_fontsize=10)
ax2.legend(fontsize=10, title='legend',title_fontsize=10)
ax3.legend(fontsize=10, title='legend',title_fontsize=10, loc='upper right')
ax4.legend(fontsize=10, title='legend',title_fontsize=10)

for ax in fig.axes:
    ax.axvline(x=0, linestyle='--', color='dimgrey')
    ax.axvline(x=18, linestyle='--', color='grey')
    ax.axvline(x=46, linestyle='--', color='darkgrey')
    ax.axvline(x=130, linestyle='--', color='silver')

#ax3.axvline(x=15, linestyle='-', color='red')
   # ax.axvline(x=50, linestyle='-', color='red')
    #ax.axvline(x=130, linestyle='-', color='red')

# %% [markdown]
# # PROVO AD APPLICARE LE NOSTRE EQUAZIONI AI DATI DI ERIKSON

# %%
eriksondf=pd.read_csv('/home/valerio/tesi/eriksondf.csv')

eriksondf['lambda']=eriksondf['lambda']/60
eriksondf['tempo']=eriksondf['tempo']*60


erikson_d_phi_r=derivata3(eriksondf.tempo,eriksondf.phi_r)

eriksondf=eriksondf.join(pd.Series(erikson_d_phi_r,name='d_phi_r'))

erikson_sigma=eriksondf['lambda']/eriksondf.phi_r

eriksondf=eriksondf.join(pd.Series(erikson_sigma,name='sigma'))

erikson_chi_r=((1/(eriksondf.sigma*eriksondf.phi_r))*eriksondf.d_phi_r)+eriksondf.phi_r

eriksondf=eriksondf.join(pd.Series(erikson_chi_r,name='chi_r'))

# %%
eriksondf
# Out:
#          tempo    lambda   phi_p_1   phi_p_2     phi_r   d_phi_r     sigma  \
# 0  -108.056872  0.007481  0.622778  0.000000  0.089378  0.000014  0.083706
# 1   -89.573460  0.007481  0.613798  0.000000  0.089637  0.000018  0.083464
# 2   -75.355450  0.007556  0.617977  0.000000  0.089983  0.000016  0.083967
# 3   -61.137441  0.007556  0.617748  0.000000  0.090098  0.000005  0.083859
# 4   -45.497630  0.007556  0.617519  0.000000  0.090136  0.000010  0.083824
# 5   -29.857820  0.007556  0.617311  0.000000  0.090408 -0.000005  0.083572
# 6   -15.639810  0.007556  0.617083  0.000000  0.089981 -0.000002  0.083969
# 7     0.000000  0.007556  0.616854  0.002827  0.090356  0.000115  0.083620
# 8    15.639810  0.010370  0.590330  0.050845  0.093590  0.000275  0.110806
# 9    29.857820  0.011407  0.533083  0.076953  0.098554  0.000343  0.115747
# 10   45.497630  0.012074  0.484628  0.098655  0.103836  0.000331  0.116280
# ...

# %%
fig=plt.figure(num=None, figsize=(9, 11), dpi=80, facecolor='w', edgecolor='k')


ax1= fig.add_subplot(4,1,1)
#ax1.set_xlim(-100,300)
ax2 = fig.add_subplot(4,1,2,sharex=ax1)
ax3= fig.add_subplot(4,1,3,sharex=ax1)
ax4= fig.add_subplot(4,1,4,sharex=ax1)


#ax1.set_xlabel("time", fontsize=15)
ax1.set_ylabel('$\lambda_{bs}$', fontsize=25)

#ax2.set_xlabel("time", fontsize=15)
ax2.set_ylabel('$\phi_R$', fontsize=25)

#ax3.set_xlabel("time", fontsize=15)
ax3.set_ylabel('$\sigma$', fontsize=25)

ax4.set_xlabel("time", fontsize=25)
ax4.set_ylabel('$\chi_R$', fontsize=25)


ax1.plot(eriksondf.tempo,eriksondf.phi_r, color='dodgerblue', linewidth=3)

ax2.plot(eriksondf.tempo, eriksondf['lambda'],color='blue', linewidth=4)

ax3.plot(eriksondf.tempo, eriksondf.sigma,color='green', linewidth=4)

ax4.plot(eriksondf.tempo, eriksondf.chi_r,color='black', linewidth=4)

# %%
#eriksondf

# %%
fig10=plt.figure(num=None, figsize=(15,8), dpi=80, facecolor='w', edgecolor='k')
gs1=fig10.add_gridspec(2,2)
ax1=fig10.add_subplot(gs1[:,0])
ax2=fig10.add_subplot(gs1[0,1])
ax3=fig10.add_subplot(gs1[1,1])

ax1.tick_params(which='major', length=10, labelsize=20)
ax2.tick_params(which='major', length=10, labelsize=20)
ax3.tick_params(which='major', length=10, labelsize=20)

ax1.set_title('Scatterplot $\chi_R$ vs $\sigma$ Erikson', fontsize=25)
ax2.set_title('Temporal series $\chi_R$ and $\sigma$ Erikson', fontsize=25)

cm= plt.cm.get_cmap('jet')

#ax3.set_xlim(-100,300)
#ax2.set_xlim(-100,300)

ax3.set_xlabel("time", fontsize=30)
ax1.set_xlabel('$\sigma$', fontsize=35)
ax1.set_ylabel('$\chi_R$', fontsize=35)

ax3.plot(eriksondf.tempo,eriksondf.sigma, 'g-', linewidth=4)
ax2.plot(eriksondf.tempo,eriksondf.chi_r, '-',color='orange', linewidth=4)
sc=ax1.scatter(eriksondf.sigma, eriksondf.chi_r,c=eriksondf.tempo, cmap='jet')
plt.colorbar(sc,ax=ax1, ticks=np.linspace(-100,400,11))

ax3.axvline(x=0, linestyle='--', color='grey')
ax2.axvline(x=0, linestyle='--', color='grey')

ax3.text(200,0.0950,'$\sigma$', fontsize=40)
ax2.text(200,0.1,'$\chi_R$', fontsize=40)
# Out:
# Text(200, 0.1, '$\\chi_R$')
