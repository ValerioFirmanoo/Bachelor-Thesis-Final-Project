# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np
import os
import os.path
import scipy 
import networkx as nx
#from math import pow
import math
import cmath
from numpy.polynomial.polynomial import polyfit

#Carica librerie python e libreria funzioni.py

# %run function.py

# %%
#P1longori plot di tutte le repliche
fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )

for i in p1longori3_index:
    df_p1longori=read_replica_tot('P1longori3',i)
    t_bin_mean=bin_mean(df_p1longori.tTrans,(df_p1longori.Itot/df_p1longori.V),10,20,-300,450,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-',markersize=4, linewidth=0.7, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %% [markdown]
# !!!!!!! C'È CHIARAMENTE UNA REPLICA (20160509) CHE NON È CORRETTA, LA ELIMINO DAL PLOT
# P.S. LA REPLICA SBAGLIATA È ANCHE L'ULTIMA

# %%
#plot correto P1longori repliche

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)


for i in p1longori3_index[:-1]:
    df_p1longori=read_replica_tot('P1longori3',i)
    t_bin_mean=bin_mean(df_p1longori.tTrans,(df_p1longori.Itot/df_p1longori.V),10,20,-300,450,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-',markersize=4, linewidth=0.7, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#plot correto P1longori repliche unificate

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p1longori=unify_replicas_tot('P1longori3', p1longori3_index)

t_bin_mean=bin_mean(unified_p1longori.tTrans,(unified_p1longori.Itot/unified_p1longori.V),10,20,-300,450,interval='custom')
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-',markersize=4, linewidth=0.7, label= 'unified replicas')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p1longori=unify_replicas_tot('P1longori3', p1longori3_index)

t_bin_mean=bin_mean(unified_p1longori.tTrans,(1-(unified_p1longori.Itot/unified_p1longori.V)),10,20,-300,450,interval='custom')
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-',markersize=4, linewidth=0.7, label= 'unified replicas')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
#plot correto P1longter repliche

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)


for i in p1longter3_index:
    df_p1longter=read_replica_tot('P1longter3',i)
    t_bin_mean=bin_mean(df_p1longter.tTrans,(df_p1longter.Itot/df_p1longter.V),10,20,-300,450,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-' ,markersize=4,linewidth=0.7, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#plot correto P1longter repliche unificate

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p1longter=unify_replicas_tot('P1longter3', p1longter3_index)

t_bin_mean=bin_mean(unified_p1longter.tTrans,(unified_p1longter.Itot/unified_p1longter.V),10,20,-300,450,interval='custom')
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-',markersize=4, linewidth=0.7, label= 'unified replicas')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
#plot correto P5ori repliche

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)


for i in p5ori3_index:
    df_p5ori=read_replica_tot('P5ori3',i)
    t_bin_mean=bin_mean(df_p5ori.tTrans,(df_p5ori.Itot/df_p5ori.V),10,20,-300,450,interval='custom')
    ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-' ,markersize=4,linewidth=0.7, label= str(i))
    ax.legend(fontsize=15, title='repliche',title_fontsize=15)

# %%
#plot correto P5ori repliche unificate

fig=plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot( )
ax.set_xlabel("time", fontsize=20)
ax.set_ylabel('Fluorescenza/Volume', fontsize=15)

unified_p5ori=unify_replicas_tot('P5ori3', p5ori3_index)

t_bin_mean=bin_mean(unified_p5ori.tTrans,(unified_p5ori.Itot/unified_p5ori.V),10,20,-300,450,interval='custom')
ax.plot(np.linspace(-300,400,len(t_bin_mean)),t_bin_mean, 'o-',markersize=4, linewidth=0.7, label= 'unified replicas')
ax.legend(fontsize=15, title='legend',title_fontsize=15)

# %%
#media binnata di scipy
temporal_scipy=scipy.stats.binned_statistic(unified_df.t0Trans,(unified_df.Itot0/df_prova.V0), statistic='mean', range=(-300,450), bins=70)

# %%
plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(temporal_scipy[1][1:],temporal_scipy[0], 'bo-' )

# %%
plt.figure(num=None, figsize=(12, 4), dpi=80, facecolor='w', edgecolor='k')
plt.plot(np.linspace(-300,400,len(temporal_bin_mean)),temporal_bin_mean, 'bo-' )
